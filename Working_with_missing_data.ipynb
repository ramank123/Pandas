# %% [markdown]
# <a href="https://colab.research.google.com/github/ramank123/Pandas/blob/main/Working_with_missing_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
df = pd.DataFrame(
    np.random.randn(5, 3),
    index=["a", "c", "e", "f", "h"],
    columns=["one", "two", "three"],
)


df["four"] = "bar"

df["five"] = df["one"] > 0

# %%
df
# Out:
#         one       two     three four   five
# a -1.364568 -1.399343 -0.709584  bar  False
# c  1.006688 -0.753678  0.300014  bar   True
# e  0.237258 -0.627598 -0.313282  bar   True
# f -0.295800  1.380749 -1.515091  bar  False
# h  0.365440  2.100392  1.408104  bar   True

# %%
df2 = df.reindex(["a", "b", "c", "d", "e", "f", "g", "h"])

# %%
df2
# Out:
#         one       two     three four   five
# a -1.364568 -1.399343 -0.709584  bar  False
# b       NaN       NaN       NaN  NaN    NaN
# c  1.006688 -0.753678  0.300014  bar   True
# d       NaN       NaN       NaN  NaN    NaN
# e  0.237258 -0.627598 -0.313282  bar   True
# f -0.295800  1.380749 -1.515091  bar  False
# g       NaN       NaN       NaN  NaN    NaN
# h  0.365440  2.100392  1.408104  bar   True

# %%
df2["one"]
# Out:
# a   -1.364568
# b         NaN
# c    1.006688
# d         NaN
# e    0.237258
# f   -0.295800
# g         NaN
# h    0.365440
# Name: one, dtype: float64

# %%
pd.isna(df2["one"])
# Out:
# a    False
# b     True
# c    False
# d     True
# e    False
# f    False
# g     True
# h    False
# Name: one, dtype: bool

# %%
df2["four"].notna()
# Out:
# a     True
# b    False
# c     True
# d    False
# e     True
# f     True
# g    False
# h     True
# Name: four, dtype: bool

# %%
df2.isna()
# Out:
#      one    two  three   four   five
# a  False  False  False  False  False
# b   True   True   True   True   True
# c  False  False  False  False  False
# d   True   True   True   True   True
# e  False  False  False  False  False
# f  False  False  False  False  False
# g   True   True   True   True   True
# h  False  False  False  False  False

# %%
df2["one"] == np.nan
# Out:
# a    False
# b    False
# c    False
# d    False
# e    False
# f    False
# g    False
# h    False
# Name: one, dtype: bool

# %%
pd.Series([1, 2, np.nan, 4], dtype=pd.Int64Dtype())
# Out:
# 0       1
# 1       2
# 2    <NA>
# 3       4
# dtype: Int64

# %%
df2 = df.copy()
df2
# Out:
#         one       two     three four   five
# a -1.364568 -1.399343 -0.709584  bar  False
# c  1.006688 -0.753678  0.300014  bar   True
# e  0.237258 -0.627598 -0.313282  bar   True
# f -0.295800  1.380749 -1.515091  bar  False
# h  0.365440  2.100392  1.408104  bar   True

# %%
df2["timestamp"] = pd.Timestamp("20120101")

# %%
df2
# Out:
#         one       two     three four   five  timestamp
# a -1.364568 -1.399343 -0.709584  bar  False 2012-01-01
# c  1.006688 -0.753678  0.300014  bar   True 2012-01-01
# e  0.237258 -0.627598 -0.313282  bar   True 2012-01-01
# f -0.295800  1.380749 -1.515091  bar  False 2012-01-01
# h  0.365440  2.100392  1.408104  bar   True 2012-01-01

# %%
df2.loc[["a", "c", "h"], ["one", "timestamp"]] = np.nan

df2
# Out:
#         one       two     three four   five  timestamp
# a       NaN -1.399343 -0.709584  bar  False        NaT
# c       NaN -0.753678  0.300014  bar   True        NaT
# e  0.237258 -0.627598 -0.313282  bar   True 2012-01-01
# f -0.295800  1.380749 -1.515091  bar  False 2012-01-01
# h       NaN  2.100392  1.408104  bar   True        NaT

# %%
df2.dtypes.value_counts()
# Out:
# float64           3
# object            1
# bool              1
# datetime64[ns]    1
# dtype: int64

# %%
s = pd.Series([1, 2, 3])
s.loc[0] = None
s
# Out:
# 0    NaN
# 1    2.0
# 2    3.0
# dtype: float64

# %%
s = pd.Series(["a", "b", "c"])
s.loc[0] = None
s.loc[1] = np.nan
s
# Out:
# 0    None
# 1     NaN
# 2       c
# dtype: object

# %%
df
# Out:
#         one       two     three four   five
# a -1.364568 -1.399343 -0.709584  bar  False
# c  1.006688 -0.753678  0.300014  bar   True
# e  0.237258 -0.627598 -0.313282  bar   True
# f -0.295800  1.380749 -1.515091  bar  False
# h  0.365440  2.100392  1.408104  bar   True

# %%
df["one"].sum()
# Out:
# -0.050983653711757726

# %%
df.mean(1)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   """Entry point for launching an IPython kernel.
# a   -0.868374
# c    0.388256
# e    0.074095
# f   -0.107536
# h    1.218484
# dtype: float64

# %%
df.cumsum()
# Out:
#         one       two     three             four  five
# a -1.364568 -1.399343 -0.709584              bar     0
# c -0.357881 -2.153021 -0.409570           barbar     1
# e -0.120623 -2.780619 -0.722851        barbarbar     2
# f -0.416423 -1.399869 -2.237942     barbarbarbar     2
# h -0.050984  0.700523 -0.829838  barbarbarbarbar     3

# %%
df.cumsum(skipna=False)
# Out:
#         one       two     three             four  five
# a -1.364568 -1.399343 -0.709584              bar     0
# c -0.357881 -2.153021 -0.409570           barbar     1
# e -0.120623 -2.780619 -0.722851        barbarbar     2
# f -0.416423 -1.399869 -2.237942     barbarbarbar     2
# h -0.050984  0.700523 -0.829838  barbarbarbarbar     3

# %%
pd.Series([np.nan]).sum()
# Out:
# 0.0

# %%
pd.Series([], dtype="float64").prod()
# Out:
# 1.0

# %%
df
# Out:
#         one       two     three four   five
# a -1.364568 -1.399343 -0.709584  bar  False
# c  1.006688 -0.753678  0.300014  bar   True
# e  0.237258 -0.627598 -0.313282  bar   True
# f -0.295800  1.380749 -1.515091  bar  False
# h  0.365440  2.100392  1.408104  bar   True

# %%
df.groupby("one").mean()
# Out:
#                 two     three  five
# one
# -1.364568 -1.399343 -0.709584   0.0
# -0.295800  1.380749 -1.515091   0.0
#  0.237258 -0.627598 -0.313282   1.0
#  0.365440  2.100392  1.408104   1.0
#  1.006688 -0.753678  0.300014   1.0

# %%
df2
# Out:
#         one       two     three four   five  timestamp
# a       NaN -1.399343 -0.709584  bar  False        NaT
# c       NaN -0.753678  0.300014  bar   True        NaT
# e  0.237258 -0.627598 -0.313282  bar   True 2012-01-01
# f -0.295800  1.380749 -1.515091  bar  False 2012-01-01
# h       NaN  2.100392  1.408104  bar   True        NaT

# %%
df2.fillna(0)
# Out:
#         one       two     three four   five            timestamp
# a  0.000000 -1.399343 -0.709584  bar  False                    0
# c  0.000000 -0.753678  0.300014  bar   True                    0
# e  0.237258 -0.627598 -0.313282  bar   True  2012-01-01 00:00:00
# f -0.295800  1.380749 -1.515091  bar  False  2012-01-01 00:00:00
# h  0.000000  2.100392  1.408104  bar   True                    0

# %%
df2["one"].fillna("missing")
# Out:
# a     missing
# c     missing
# e    0.237258
# f     -0.2958
# h     missing
# Name: one, dtype: object

# %%
df
# Out:
#         one       two     three four   five
# a -1.364568 -1.399343 -0.709584  bar  False
# c  1.006688 -0.753678  0.300014  bar   True
# e  0.237258 -0.627598 -0.313282  bar   True
# f -0.295800  1.380749 -1.515091  bar  False
# h  0.365440  2.100392  1.408104  bar   True

# %%
dff = pd.DataFrame(np.random.randn(10, 3), columns=list("ABC"))
dff.iloc[3:5, 0] = np.nan
dff.iloc[4:6, 1] = np.nan
dff.iloc[5:8, 2] = np.nan
dff
# Out:
#           A         B         C
# 0 -0.255367 -0.539230  2.847722
# 1  0.108969  1.413062  0.272874
# 2 -0.628343  0.032028  0.253052
# 3       NaN  1.475702 -2.411105
# 4       NaN       NaN  1.772390
# 5 -0.632499       NaN       NaN
# 6  0.040124 -0.632280       NaN
# 7 -0.317891  0.979361       NaN
# 8 -0.958165  0.697490  0.561473
# 9  1.580480  0.889468  2.156919

# %%
dff.fillna(dff.mean())
# Out:
#           A         B         C
# 0 -1.335023 -2.052158 -0.644278
# 1 -0.341800  0.495224 -1.467893
# 2  0.384548 -1.368252  0.919045
# 3 -0.276416  0.486822 -0.072087
# 4 -0.276416 -0.550365 -0.149780
# 5  1.051745 -0.550365 -0.435179
# 6  0.204043  0.839498 -0.435179
# 7 -0.992040 -1.832423 -0.435179
# 8 -1.854172 -1.165221 -1.498277
# 9  0.671370  0.193584 -0.132981

# %%
dff.fillna(dff.mean()["B":"C"])
# Out:
#           A         B         C
# 0 -0.255367 -0.539230  2.847722
# 1  0.108969  1.413062  0.272874
# 2 -0.628343  0.032028  0.253052
# 3       NaN  1.475702 -2.411105
# 4       NaN  0.539450  1.772390
# 5 -0.632499  0.539450  0.779046
# 6  0.040124 -0.632280  0.779046
# 7 -0.317891  0.979361  0.779046
# 8 -0.958165  0.697490  0.561473
# 9  1.580480  0.889468  2.156919

# %%
df
# Out:
#         one       two     three four   five
# a -1.364568 -1.399343 -0.709584  bar  False
# c  1.006688 -0.753678  0.300014  bar   True
# e  0.237258 -0.627598 -0.313282  bar   True
# f -0.295800  1.380749 -1.515091  bar  False
# h  0.365440  2.100392  1.408104  bar   True

# %%
df.dropna(axis=0)
# Out:
#         one       two     three four   five
# a -1.364568 -1.399343 -0.709584  bar  False
# c  1.006688 -0.753678  0.300014  bar   True
# e  0.237258 -0.627598 -0.313282  bar   True
# f -0.295800  1.380749 -1.515091  bar  False
# h  0.365440  2.100392  1.408104  bar   True

# %%
df.dropna(axis=1)
# Out:
#         one       two     three four   five
# a -1.364568 -1.399343 -0.709584  bar  False
# c  1.006688 -0.753678  0.300014  bar   True
# e  0.237258 -0.627598 -0.313282  bar   True
# f -0.295800  1.380749 -1.515091  bar  False
# h  0.365440  2.100392  1.408104  bar   True
